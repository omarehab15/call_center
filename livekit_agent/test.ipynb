# %%
# !pip install elevenlabs
# Out:
# Collecting elevenlabs
#   Downloading elevenlabs-2.56.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: httpx>=0.21.2 in c:\users\ehab6\miniconda3\lib\site-packages (from elevenlabs) (0.27.2)
# Requirement already satisfied: pydantic>=1.9.2 in c:\users\ehab6\miniconda3\lib\site-packages (from elevenlabs) (2.8.2)
# Requirement already satisfied: pydantic-core>=2.18.2 in c:\users\ehab6\miniconda3\lib\site-packages (from elevenlabs) (2.20.1)
# Requirement already satisfied: requests>=2.20 in c:\users\ehab6\miniconda3\lib\site-packages (from elevenlabs) (2.32.5)
# Requirement already satisfied: typing_extensions>=4.0.0 in c:\users\ehab6\miniconda3\lib\site-packages (from elevenlabs) (4.15.0)
# Requirement already satisfied: websockets>=13.0 in c:\users\ehab6\miniconda3\lib\site-packages (from elevenlabs) (15.0.1)
# Requirement already satisfied: anyio in c:\users\ehab6\miniconda3\lib\site-packages (from httpx>=0.21.2->elevenlabs) (4.11.0)
# Requirement already satisfied: certifi in c:\users\ehab6\miniconda3\lib\site-packages (from httpx>=0.21.2->elevenlabs) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\ehab6\miniconda3\lib\site-packages (from httpx>=0.21.2->elevenlabs) (1.0.9)
# Requirement already satisfied: idna in c:\users\ehab6\miniconda3\lib\site-packages (from httpx>=0.21.2->elevenlabs) (3.11)
# Requirement already satisfied: sniffio in c:\users\ehab6\miniconda3\lib\site-packages (from httpx>=0.21.2->elevenlabs) (1.3.1)
# Requirement already satisfied: h11>=0.16 in c:\users\ehab6\miniconda3\lib\site-packages (from httpcore==1.*->httpx>=0.21.2->elevenlabs) (0.16.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ehab6\miniconda3\lib\site-packages (from pydantic>=1.9.2->elevenlabs) (0.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ehab6\miniconda3\lib\site-packages (from requests>=2.20->elevenlabs) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ehab6\miniconda3\lib\site-packages (from requests>=2.20->elevenlabs) (2.3.0)
# Downloading elevenlabs-2.56.0-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 1.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.8 MB 1.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 1.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.3 MB/s  0:00:01
# Installing collected packages: elevenlabs
# Successfully installed elevenlabs-2.56.0

# %%
from elevenlabs import ElevenLabs

client = ElevenLabs(api_key="sk_adbbe87d3c1fcb957d70d641b76ff00d0177985812ef820e")

voice = client.voices.get("9koBc4DQZJE0dLobwFBt")
print(voice)
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[1], line 5
#       1 from elevenlabs import ElevenLabs
#       3 client = ElevenLabs(api_key="sk_adbbe87d3c1fcb957d70d641b76ff00d0177985812ef820e")
# ----> 5 voice = client.voices.get("9koBc4DQZJE0dLobwFBt")
#       6 print(voice)
#
# File c:\Users\ehab6\miniconda3\Lib\site-packages\elevenlabs\voices\client.py:122, in VoicesClient.get(self, voice_id, with_settings, request_options)
#      84 def get(
#      85     self,
#      86     voice_id: str,
#    (...)     89     request_options: typing.Optional[RequestOptions] = None,
#      90 ) -> Voice:
#      91     """
#      92     Returns metadata about a specific voice.
#      93
#    (...)    120     )
#     121     """
# --> 122     _response = self._raw_client.get(voice_id, with_settings=with_settings, request_options=request_options)
#     123     return _response.data
#
# File c:\Users\ehab6\miniconda3\Lib\site-packages\elevenlabs\voices\raw_client.py:144, in RawVoicesClient.get(self, voice_id, with_settings, request_options)
#     142 except JSONDecodeError:
#     143     raise ApiError(status_code=_response.status_code, headers=dict(_response.headers), body=_response.text)
# --> 144 raise ApiError(status_code=_response.status_code, headers=dict(_response.headers), body=_response_json)
#
# ApiError: headers: {'date': 'Mon, 06 Jul 2026 21:38:33 GMT', 'server': 'uvicorn', 'content-length': '197', 'content-type': 'application/json', 'vary': 'Accept-Language', 'access-control-allow-origin': '*', 'access-control-allow-headers': '*', 'access-control-allow-methods': 'POST, PATCH, OPTIONS, DELETE, GET, PUT', 'access-control-max-age': '600', 'strict-transport-security': 'max-age=1800;', 'x-trace-id': '2a53994e0f07444d390eb0d005146bea', 'x-region': 'us-central1', 'via': '1.1 google', 'alt-svc': 'h3=":443"; ma=2592000'}, status_code: 400, body: {'detail': {'type': 'not_found', 'code': 'voice_not_found', 'message': "A voice with ID '9koBc4DQZJE0dLobwFBt' was not found.", 'status': 'voice_not_found', 'request_id': '2a53994e0f07444d390eb0d005146bea'}}

# %%
"""
اختبار حقيقي لمعرفة هل الصوت متاح للتوليد الفعلي (TTS) على حسابك ولا لأ.
استبدل API_KEY و VOICE_ID بالقيم بتاعتك.
"""
from elevenlabs import ElevenLabs

API_KEY = "sk_adbbe87d3c1fcb957d70d641b76ff00d0177985812ef820e"
VOICE_ID = "XrExE9yKIg1WjnnlVkGX"

client = ElevenLabs(api_key=API_KEY)

try:
    audio = client.text_to_speech.convert(
        voice_id=VOICE_ID,
        text="اختبار",
        model_id="eleven_turbo_v2_5",
    )
    # لو السطر ده اتنفذ من غير exception، يبقى الصوت شغال فعلاً للتوليد
    with open("test_output.mp3", "wb") as f:
        for chunk in audio:
            f.write(chunk)
    print("✅ الصوت شغال ومتاح للتوليد الفعلي على حسابك")
except Exception as e:
    print("❌ الصوت مش متاح للتوليد على خطتك الحالية")
    print("تفاصيل الخطأ:", e)
# Out:
# ✅ الصوت شغال ومتاح للتوليد الفعلي على حسابك

# %%
import requests

url = "https://api.retellai.com/search-community-voice"

headers = {
    "Authorization": "key_9a0d36ee4cf3b784cfb454749c32",
    "Content-Type": "application/json",
}

data = {
    "search_query": "Hailey",
    "voice_provider": "elevenlabs"
}

r = requests.post(url, headers=headers, json=data)
print(r.json())
# Out:
# {'error_message': "Authorization header with scheme 'Bearer' required"}
